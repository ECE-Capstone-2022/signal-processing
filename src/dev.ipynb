# %% [markdown]
# ### Contact Information
#
# **Author** Marco Acea
# **Email** macea@andrew.cmu.edu
# **Github** @aceamarco
#
# ### Brief
#
# This file is used to work out the product life cycle of the Piano Pi library

# %%
from piano_pi_tmp import *
from scipy.io import wavfile
from IPython import display

audio_path = "../assets/recordings/marco_speech_18_500.wav"
display.Audio(audio_path)

sample_rate, audio_time_series = wavfile.read(audio_path)

PianoPi = PianoPi(sample_rate, 15)

PianoPi.generate_frequencies_through_time(audio_time_series[:,0])

PianoPi.generate_tsv()
# Out:
# 234777
# Creating SDTF Bin at 27.5Hz...
# Finding N and k for 27.5Hz...
# Done! Found N = 1746 and k = 1
# Done. Max window size is 3200
# ----------------------------------------
# Creating SDTF Bin at 29.135Hz...
# Finding N and k for 29.135Hz...
# Done! Found N = 1648 and k = 1
# Done. Max window size is 3200
# ----------------------------------------
# Creating SDTF Bin at 30.868Hz...
# Finding N and k for 30.868Hz...
# Done! Found N = 3111 and k = 2
# Done. Max window size is 3200
# ----------------------------------------
# Creating SDTF Bin at 32.703Hz...
# Finding N and k for 32.703Hz...
# Done! Found N = 1468 and k = 1
# Done. Max window size is 3200
# ----------------------------------------
# Creating SDTF Bin at 34.648Hz...
# Finding N and k for 34.648Hz...
# Done! Found N = 2771 and k = 2
# Done. Max window size is 3200
# ----------------------------------------
# Creating SDTF Bin at 36.708Hz...
# Finding N and k for 36.708Hz...
# Done! Found N = 1308 and k = 1
# ...
